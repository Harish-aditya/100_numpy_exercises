# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-aditya/100_numpy_exercises/blob/main/drought.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Drought Prediction Using satellite images.

# %% [markdown]
# ## Collecting images

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("Drought", limit = 100,output_dir = "images")
# Out:
# [%] Downloading Images to /content/images/Drought
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 8 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.enca.com/sites/default/files/styles/facebook/public/WEB_PHOTO_DROUGHT_071215.jpg?h=199d8c1f&amp;itok=QKDaAJGR
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.thetreefarm.com/media/catalog/product/cache/1/thumbnail/9df78eab33525d08d6e5fb8d27136e95/f/i/file_149_6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.natureasia.com/en/nmiddleeast/sliders/2244
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://mescaleroapachetribe.com/wp-content/uploads/silver-lake-page-1024x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://harlowgardens.com/wp-content/uploads/2017/03/20190701_141843_resized.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/736x/cf/d2/f7/cfd2f729bd523cfa35ad81b98a735a4e.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("green landscape", limit = 100,output_dir = "images")
# Out:
# [%] Downloading Images to /content/images/green landscape
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 17 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://1.bp.blogspot.com/-sULESYCN-WA/TjzsVPayyrI/AAAAAAAAA2o/m0OL09r-fu0/s1600/311.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://live.staticflickr.com/5133/29508427153_a0d981c7cc_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/b/green-landscape-23266001.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/XHmNrwiZuGI/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-lagw4cFC5EU/Tjzs_D554GI/AAAAAAAAA34/LAb_VSNpTWA/s1600/Green_Landscape.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://images.freeimages.com/images/large-previews/98c/green-landscape-1315637.jpg
# [%] File Downloaded !
#
# ...

# %%
import os

# %%
file_path = "/content/images/Drought"

# %%
count = 0
for i in file_path:
  count += 1
print(count)
# Out:
# 23

# %%
# echo "Downloading data"
# curl -SL https://storage.googleapis.com/wandb_datasets/dw_train_86K_val_10K.zip > dw_data.zip
# unzip dw_data.zip
# rm dw_data.zip
# mv droughtwatch_data/ data/
# Out:
#   File "<ipython-input-1-39472ca98212>", line 1
#     echo "Downloading data"
#                           ^
# SyntaxError: invalid syntax
